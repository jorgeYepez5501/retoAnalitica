# %%
# Umizoomi
Santiago Orozco Quintero
Jorge Yepez Frutos
Jorge Gerardo Iglesias Ortiz
Alejandro Hernández De la Torre
Carlos Andrés Barredez Ríos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df = pd.read_csv("covid19_tweets.csv")
print(df)
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# ...

# %%
df.head(30)
# Out:
#                                user_name  \
# 0                                 ᏉᎥ☻լꂅϮ
# 1                          Tom Basile 🇺🇸
# 2                        Time4fisticuffs
# 3                            ethel mertz
# 4                               DIPR-J&K
# 5                       🎹 Franz Schubert
# 6                           hr bartender
# 7                         Derbyshire LPC
# 8                      Prathamesh Bendre
# 9      Member of Christ 🇨🇳🇺🇸🇮🇳🇮🇩🇧🇷🇳🇬🇧🇩🇷🇺
# 10                Voice Of CBSE Students
# 11                           Creativegms
# 12                            SEXXYLYPPS
# 13    Africa Youth Advisory Board on DRR
# 14                        DailyaddaaNews
# 15                         Dimapur 24/7.
# 16                        ChennaiCityNow
# 17                  marc goovaerts🇪🇺🏳️‍🌈
# 18                            Dorian Aur
# 19                       Coronavirus Law
# 20                     The Voice of GenX
# 21                     APO Group English
# ...

# %%
df.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    7.443600e+04   74436.000000     7.443600e+04
# mean     1.059513e+05    2154.721170     1.529747e+04
# std      8.222900e+05    9365.587474     4.668971e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.660000e+02     153.000000     2.200000e+02
# 50%      9.600000e+02     552.000000     1.927000e+03
# 75%      5.148000e+03    1780.250000     1.014800e+04
# max      1.389284e+07  497363.000000     2.047197e+06

# %%
df.sort_values(['user_followers'], ascending = False).head(10)
# Out:
#       user_name   user_location  \
# 6959       CGTN  Beijing, China
# 13450      CGTN  Beijing, China
# 16194      CGTN  Beijing, China
# 235        CGTN  Beijing, China
# 2837       CGTN  Beijing, China
# 5344       CGTN  Beijing, China
# 20483      CGTN  Beijing, China
# 20378      CGTN  Beijing, China
# 24243      CGTN  Beijing, China
# 23721      CGTN  Beijing, China
#
#                                         user_description         user_created  \
# 6959   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 13450  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 16194  #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 235    #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 2837   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# 5344   #SeeTheDifference with CGTN as we bring you st...  2013-01-24 03:18:59
# ...

# %%
plt.boxplot(df[["user_followers", "user_friends", "user_favourites"]])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.corr(method = "kendall")
# Out:
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000      0.410663         0.242534       0.415364
# user_friends           0.410663      1.000000         0.439099      -0.003114
# user_favourites        0.242534      0.439099         1.000000      -0.032220
# user_verified          0.415364     -0.003114        -0.032220       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              1.0

# %%
df.corr(method = "pearson")
# Out:
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              NaN

# %%
ax = sns.heatmap(df[["user_followers", "user_friends", "user_favourites"]])

# %% [raw]
# Basándose en la media, mediana y desviación estándar de cada variable, ¿Qué conclusiones puedes entregar de los datos?
#
# Al basarse en los datos que se obtuvieron de distintas variables se puede deducir que los distintos usuarios hacen publicaciones acerca de distintos temas como lo son huracanes, la tendencia que se dio del Covid19, entre otras cosas y también se puede identificar las procedencias que tiene cada uno de las personas que publicaron los hashtags juntos con la fecha de creación y los seguidores.
# Dichos datos dan a entender cuál es la popularidad que tienen los usuarios y el saber si están verificados o no lo están por lo que se puede entender que si un usuario tuviera más seguidores y retweets, entonces tendrían un canal el cual se tuviera mayor prestigio en la información o las publicaciones que se hicieron a través de esa cuenta. Asimismo, también se puede entender cómo es que se empezaron los casos a través de la hora en la que se hicieron todas las publicaciones por lo que se puede dar un seguimiento para una posible publicación, además de que también se podría saber cómo está la situación en esos lugares debido a los diferentes lugares ya sea ciudades o países en donde se encuentran todos los usuarios.
# Por último, cabe mencionar que, gracias a todos estos datos, se puede dar cuenta de qué tan viable sería toda la información que hay dentro de Twitter debido a la tendencia que tiene y si estas cuentas son falsas o bots o son reales a través de la verificación, la fecha de creación de los usuarios, su número de seguidores y las publicaciones que estos hacen para saber qué tan real o qué tan falsa sería la información.
